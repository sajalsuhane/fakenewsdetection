# %% [markdown]
# # Fake News Detection

# %% [markdown]
# This notebook contains code that takes data from a csv file and checks whether the journalised news is fake or not based on various parameters.

# %%
    import numpy as np
    import pandas as pd
    import itertools
    from sklearn.model_selection import train_test_split
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.linear_model import PassiveAggressiveClassifier
    from sklearn.metrics import accuracy_score, confusion_matrix

# %%
    #Read the data
    df=pd.read_csv('https://raw.githubusercontent.com/sajalsuhane/fakenewsdetection/master/news.csv')
    #Get shape and head
    df.shape
    df.head()
# Out:
#   Unnamed: 0                                              title  \
# 0        384         Debate Goals for the Democratic Candidates
# 1       4492  'Spinning up as we speak': Email shows Pentago...
# 2       2432  A Case Study On Why The Obamacare Lawsuit Is B...
# 3       5307  Trump Proudly Declares: Most Of The People I’v...
# 4       8484      Dems sue GOP over Trump's 'rigged' complaints
#
#                                                 text label Unnamed: 4  \
# 0  Five candidates will be on stage Tuesday at th...  REAL        NaN
# 1  As the attack on the U.S. consulate in Benghaz...  REAL        NaN
# 2  The Bentley administration, the Alabama legisl...  REAL        NaN
# 3  Trump Proudly Declares: Most Of The People I’v...  FAKE        NaN
# 4  Dems sue GOP over Trump's 'rigged' complaints ...  FAKE        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 131  \
# 0        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 2        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 3        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 4        NaN        NaN        NaN        NaN        NaN  ...          NaN
#
#   Unnamed: 132 Unnamed: 133 Unnamed: 134 Unnamed: 135 Unnamed: 136  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 137 Unnamed: 138 Unnamed: 139 Unnamed: 140
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 141 columns]

# %%
df.drop(df.iloc[:, 5:141], inplace = True, axis = 1)

# %%
df.head()
# Out:
#   Unnamed: 0                                              title  \
# 0        384         Debate Goals for the Democratic Candidates
# 1       4492  'Spinning up as we speak': Email shows Pentago...
# 2       2432  A Case Study On Why The Obamacare Lawsuit Is B...
# 3       5307  Trump Proudly Declares: Most Of The People I’v...
# 4       8484      Dems sue GOP over Trump's 'rigged' complaints
#
#                                                 text label Unnamed: 4
# 0  Five candidates will be on stage Tuesday at th...  REAL        NaN
# 1  As the attack on the U.S. consulate in Benghaz...  REAL        NaN
# 2  The Bentley administration, the Alabama legisl...  REAL        NaN
# 3  Trump Proudly Declares: Most Of The People I’v...  FAKE        NaN
# 4  Dems sue GOP over Trump's 'rigged' complaints ...  FAKE        NaN

# %%
df.drop(['Unnamed: 4'],axis=1)
# Out:
#      Unnamed: 0                                              title  \
# 0           384         Debate Goals for the Democratic Candidates
# 1          4492  'Spinning up as we speak': Email shows Pentago...
# 2          2432  A Case Study On Why The Obamacare Lawsuit Is B...
# 3          5307  Trump Proudly Declares: Most Of The People I’v...
# 4          8484      Dems sue GOP over Trump's 'rigged' complaints
# 5          9948  US Airstrikes on Iraqi Army Slowing Advance on...
# 6          2916                  Iran letter blowback startles GOP
# 7          6058    Clinton Camp Desperate, Russia Trains for WWIII
# 8          4713                       Donald Trump's GOP civil war
# 9          8767  Comment on Tainted Measles Vaccine Kills More ...
# 10         4217  Laura Bush hints she'd rather see Hillary as p...
# 11         1770  Scott Walker, Rick Perry show limits of super ...
# 12         9394              If Catcalls Were Politically Correct…
# 13         8428   Why Hillary Won't Unleash WWIII    : Information
# 14         3427  Is It Time To Reconsider Lifetime Appointments...
# 15          658  Clinton has delegates to win Dem nomination, A...
# 16        10357  Hillary IMPLODES: Trump 'Took Everything...Pai...
# 17         4865  Trump says Obama born in US, ‘period’ – after ...
# 18         4031  MH370: If debris is part of missing plane, wha...
# 19        10257  GOOGLE PLANNED MASSIVE AI INTEGRATED SOCIAL NE...
# 20         2586  Israel stole classified US information and use...
# 21         4045  "America has a simple ideology": how one of Ru...
# 22         4632  Poll shows Trump made up 13 points in under 2 ...
# 23           71  Chaos on House floor as Dems, Republicans clas...
# 24         7577  New Study Links Fluoride Consumption To Hypoth...
# 25         1108  Clinton, Sanders accuse Trump of inciting viol...
# 26         9485  Memo to the Next Administration: Defense Spend...
# 27         4701  In New Responses, Hillary Clinton Insists Emai...
# 28         4929  Trump mulls alternative options for making Mex...
# 29         6698  The circus of liars - America's three rings of...
# ...         ...                                                ...
# 7260        NaN                                                NaN
# 7261        NaN                                                NaN
# 7262        NaN                                                NaN
# 7263        NaN                                                NaN
# 7264        NaN                                                NaN
# 7265        NaN                                                NaN
# 7266        NaN                                                NaN
# 7267        NaN                                                NaN
# 7268        NaN                                                NaN
# 7269        NaN                                                NaN
# 7270        NaN                                                NaN
# 7271        NaN                                                NaN
# 7272        NaN                                                NaN
# 7273        NaN                                                NaN
# 7274        NaN                                                NaN
# 7275        NaN                                                NaN
# 7276        NaN                                                NaN
# 7277        NaN                                                NaN
# 7278        NaN                                                NaN
# 7279        NaN                                                NaN
# 7280        NaN                                                NaN
# 7281        NaN                                                NaN
# 7282        NaN                                                NaN
# 7283        NaN                                                NaN
# 7284        NaN                                                NaN
# 7285        NaN                                                NaN
# 7286        NaN                                                NaN
# 7287        NaN                                                NaN
# 7288        NaN                                                NaN
# 7289        NaN                                                NaN
#
#                                                    text label
# 0     Five candidates will be on stage Tuesday at th...  REAL
# 1     As the attack on the U.S. consulate in Benghaz...  REAL
# 2     The Bentley administration, the Alabama legisl...  REAL
# 3     Trump Proudly Declares: Most Of The People I’v...  FAKE
# 4     Dems sue GOP over Trump's 'rigged' complaints ...  FAKE
# 5     By Gordon Duff, Senior Editor on October 29, 2...  FAKE
# 6     The Manhattan billionaire made the announcemen...  REAL
# 7     Clinton Camp Desperate, Russia Trains for WWII...  FAKE
# 8     Panama City, Florida (CNN) Donald Trump is tea...  REAL
# 9     Photos Credits: Social Media The so called “ o...  FAKE
# 10    “I want our next president – whoever he or she...  REAL
# 11    On this day in 1973, J. Fred Buzhardt, a lawye...  REAL
# 12    By wmw_admin on September 16, 2008 \nThe ‘dots...  FAKE
# 13     Why Hillary Won't Unleash WWIII By Pepe Escob...  FAKE
# 14    Is It Time To Reconsider Lifetime Appointments...  REAL
# 15    Hillary Clinton has earned enough delegates to...  REAL
# 16        Hillary Clinton can’t believe she’s losing.    FAKE
# 17    Donald Trump tried to tamp down a newly revive...  REAL
# 18    (CNN) If confirmed to be from missing Malaysia...  REAL
# 19    GOOGLE PLANNED MASSIVE AI INTEGRATED SOCIAL NE...  FAKE
# 20    The Wall Street Journal's Adam Entous dropped ...  REAL
# 21    The United States comes up constantly when you...  REAL
# 22    While Trump’s edge is just 1 point — which is ...  REAL
# 23    The chaotic scene -- accompanied by loud chant...  REAL
# 24    Fluoridation of public water supplies as well ...  FAKE
# 25    (CNN) Hillary Clinton and Bernie Sanders both ...  REAL
# 26    Written by Ron Paul Sunday November 13, 2016 I...  FAKE
# 27    In New Responses, Hillary Clinton Insists Emai...  REAL
# 28    While Donald Trump doubled down this week on h...  REAL
# 29    Wed, 26 Oct 2016 18:19 UTC © Jen Psaki Preside...  FAKE
# ...                                                 ...   ...
# 7260                                                NaN   NaN
# 7261                                                NaN   NaN
# 7262                                                NaN   NaN
# 7263                                                NaN   NaN
# 7264                                                NaN   NaN
# 7265                                                NaN   NaN
# 7266                                                NaN   NaN
# 7267                                                NaN   NaN
# 7268                                                NaN   NaN
# 7269                                                NaN   NaN
# 7270                                                NaN   NaN
# 7271                                                NaN   NaN
# 7272                                                NaN   NaN
# 7273                                                NaN   NaN
# 7274                                                NaN   NaN
# 7275                                                NaN   NaN
# 7276                                                NaN   NaN
# 7277                                                NaN   NaN
# 7278                                                NaN   NaN
# 7279                                                NaN   NaN
# 7280                                                NaN   NaN
# 7281                                                NaN   NaN
# 7282                                                NaN   NaN
# 7283                                                NaN   NaN
# 7284                                                NaN   NaN
# 7285                                                NaN   NaN
# 7286                                                NaN   NaN
# 7287                                                NaN   NaN
# 7288                                                NaN   NaN
# 7289                                                NaN   NaN
#
# [7290 rows x 4 columns]

# %%
labels=df.label
labels.head()
# Out:
# 0    REAL
# 1    REAL
# 2    REAL
# 3    FAKE
# 4    FAKE
# Name: label, dtype: object

# %%
df['text']= df.text.astype(str)
x_train,x_test,y_train,y_test=train_test_split(df['text'], labels, test_size=0.2, random_state=7)
labels.head()
# Out:
# 0    REAL
# 1    REAL
# 2    REAL
# 3    FAKE
# 4    FAKE
# Name: label, dtype: object

# %%
    #DataFlair - Initialize a TfidfVectorizer
    tfidf_vectorizer=TfidfVectorizer(stop_words='english', max_df=0.7)
    #DataFlair - Fit and transform train set, transform test set
    tfidf_train=tfidf_vectorizer.fit_transform(x_train) 
    tfidf_test=tfidf_vectorizer.transform(x_test)

# %%
    #DataFlair - Initialize a PassiveAggressiveClassifier
    pac=PassiveAggressiveClassifier(max_iter=50)
    pac.fit(tfidf_train,y_train)
    #DataFlair - Predict on the test set and calculate accuracy
    y_pred=pac.predict(tfidf_test)
    score=accuracy_score(y_test,y_pred)
   
    print(f'Accuracy: {round(score*100,2)}%')
# Out:
# Accuracy: 88.41%

# %%
#DataFlair - Build confusion matrix
if score>=0.85:
    print("The prediction is most likely correct. Please check the csv file for results")
elif score>=0.60 and score<0.85 :
    print("The prediction may be correct. Please check the csv file for results")
else:
    print("Please re-run the model for better accuracy results")
    
confusion_matrix(y_test,y_pred, labels=['FAKE','REAL'])
# Out:
# The prediction is most likely correct. Please check the csv file for results
# array([[478,  30],
#        [ 32, 492]])

# %%
y_pred
# Out:
# array(['FAKE', 'FAKE', 'FAKE', ..., 'FAKE', 'REAL', 'REAL'],
#       dtype='<U1091')
